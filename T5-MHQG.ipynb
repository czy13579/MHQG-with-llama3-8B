# %%
# %%time
# !pip install pycocoevalcap
# !pip install bert_score

# %%
## 计算模型测试结果的bleu4和bert_score
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.meteor.meteor import Meteor
from pycocoevalcap.rouge.rouge import Rouge
from bert_score import BERTScorer
import numpy as np

bleu4_scorers = {"Bleu": Bleu(4)}
bert_scorer = BERTScorer(lang="en",
                         model_type='roberta-large',
                         device='cuda:1',
                         rescale_with_baseline=True
                        )

# 测评问题的流畅性
def fluencyScore(preds_list, gold_list):
    gts = {}
    res = {}
    for i, (p, g) in enumerate(zip(preds_list, gold_list)):
        gts[i] = [p]
        res[i] = [g]
    scores = {}
    for name, scorer in bleu4_scorers.items():
        score, all_scores = scorer.compute_score(gts, res)
        if isinstance(score, list):
            for i, sc in enumerate(score, 1):
                scores[name + str(i)] = sc
        else:
            scores[name] = score
    return scores,all_scores[-1]

# 测评语义相似度
def SemanticScore(preds_list, gold_list):
    p,r,f1 = bert_scorer.score(preds_list, gold_list, verbose=True)
    bert_score = np.mean(f1.tolist())
    return bert_score

## 合并结果
def getTotalScore(preds_list,gold_list):
    bert_score = SemanticScore(preds_list,gold_list)
    scores,all_scores = fluencyScore(preds_list,gold_list)
    last_score = (bert_score/2+scores['Bleu4']/2)*100
    return {'TotalScore':last_score, 
            'BERTScore':bert_score,
            'Bleu1':scores['Bleu1'],
            'Bleu2':scores['Bleu2'],
            'Bleu3':scores['Bleu3'],
            'Bleu4':scores['Bleu4'],
           },all_scores

# %%
"""
model_name: 模型名称，本代码中支持不同T5型号
train_data_path,dev_data_path,test_data_path:三个数据集路径
"""
class Args:
    model_name = 'google/flan-t5-base'
    train_data_path = '/kaggle/input/scnu-ai-challenge-5/train.json'
    dev_data_path = '/kaggle/input/scnu-ai-challenge-dataset-with-sorted-pred-facts/dev.json'
    test_data_path = '/kaggle/input/scnu-ai-challenge-dataset-with-sorted-pred-facts/test.json'

## 用于记录训练过程中的loss和score
class MyLogging:
    best_score = 0
    loss_list=[]
    scores_list=[]

args = Args()
logging=MyLogging()

def plot_loss():
    import matplotlib.pyplot as plt
    loss_list=logging.loss_list
    plt.plot(range(len(loss_list)),loss_list)
    plt.show()

# %%
import json
import random
from tqdm import tqdm
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128"

import torch
from torch import nn
import torch.nn.functional as F

## 数据整理器
from transformers import DataCollatorForSeq2Seq
## 模型及分词器
from transformers import T5ForConditionalGeneration as ConditionalGeneration
from transformers import AutoTokenizer
## 优化器
from transformers.optimization import Adafactor, AdafactorSchedule
# Out:
# 2024-06-25 12:54:48.488604: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-25 12:54:48.488697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-25 12:54:48.619911: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class Trainer_config:
    pg_num=1
    max_source_length=1024
    max_target_length=128
    training_batch=512
    testing_batch=10
    updata_batch=8
    epochs=2
    batch_size=16
    eval_model=True
def get_trainer_config(pg_num,max_source_length,batch_size,updata_batch,epochs):
    config=Trainer_config()
    config.pg_num=pg_num
    config.max_source_length=max_source_length
    config.batch_size=batch_size
    config.updata_batch=updata_batch
    config.epochs=epochs
    return config

## 测试
def get_eval_config():
    config=Trainer_config()
    config.pg_num=7
    config.max_source_length=1024
    config.batch_size=4
    return config
def show_config(config):
    print('pg_num:',config.pg_num)
    print('max_souce_length:',config.max_source_length)
    print('train_batch:',config.training_batch)
    print('updata_batch:',config.updata_batch)
    print('epochs:',config.epochs)
    print('batch_size:',config.batch_size)

# %%
## 读入数据
data_dict={}
def read_json(data_path,data_type):
    if data_dict.get(data_type,-1)!=-1:
        return data_dict[data_type]
    else:
        with open(data_path, 'r', encoding='utf-8') as f:
            data =json.load(f)
        data_dict[data_type]=data
        return data

## 清洗数据及准备数据   
def get_datas(data_path,data_type):
    data=read_json(data_path,data_type)
    answers=[]
    questions=[]
    title_to_contexts=[]
    support_facts=[]
    for i,d in tqdm(enumerate(data)):
        ## 删除训练集中的单跳问题
        if data_type=='train':
            if d['level']=='easy':
                continue
        
        ## 验证集只保留难度为hard的文段，结果较为稳定
        if data_type=='dev':
            if d['level']!='hard':
                continue
        
        answer=d['answer']
        
        answer_token_num=len(answer.split(' '))
        ## 根据1-0.25*len的概率删除数据
        if data_type=='train':
            p_drop=max(1-0.25*answer_token_num,0)
            if random.random()<p_drop:
                continue
                
        ## support_facts
        support_facts_list=[]
        fact_set=set()
        if data_type=='train':
            titles=[]
            for item in d['supporting_facts']:
                fact_set.add(item[0])
            support_facts_list=list(fact_set)
        else:
            for item in d['pred_support_facts']:
                support_facts_list.append(item[0])
     
    
        ## title_to_context
        title_to_context={}   
        for x in d['context']:
            s=' '.join(x[1])
            context=f'{x[0]}. {s} '
            title_to_context[x[0]]=context
        
        ## question
        question=[]
        if data_type!='test':
            question=d['question']
        
        ## append
        questions.append(question)
        title_to_contexts.append(title_to_context)
        answers.append(answer)
        support_facts.append(support_facts_list)
        
    return title_to_contexts,questions,answers,support_facts

# %%
# %%time
## 生成训练集并打乱
train_T2C,train_Q,train_A,train_SF=get_datas(args.train_data_path,'train')
def get_infinite_data(datas):
    while True:
        for value in datas:
            yield value

train_data=list(zip(train_T2C,train_Q,train_A,train_SF))
print('train_data_num:',len(train_data))
random.shuffle(train_data)
train_data_generator=get_infinite_data(train_data)
def get_example():
    return train_data_generator.__next__()

## 将数据整理成输入格式
def get_context(title_to_context,support_facts_list,data_type='train',pg_num=7):
    if data_type=='train':
        if len(support_facts_list)>pg_num:
                support_facts_list=support_facts_list[:pg_num]
        else:
            num=pg_num-len(support_facts_list)
            titles=[]
            for title in list(title_to_context.keys()):
                if title not in support_facts_list:
                    titles.append(title)
            support_facts_list.extend(random.choices(titles,k=min(len(titles),num)))
        random.shuffle(support_facts_list)
    else:
        support_facts_list=support_facts_list[:pg_num]
        
    context=''   
    for title in support_facts_list:
        context+=title_to_context[title]
    return context

title_to_context,question,answer,support_facts_list=get_example()
get_context(title_to_context,support_facts_list,data_type='train',pg_num=2)
# Out:
# 88947it [00:00, 118844.51it/s]
# train_data_num: 37382
# CPU times: user 7.99 s, sys: 2.27 s, total: 10.3 s
# Wall time: 19.3 s
# 'Albany Medical College. Albany Medical College (AMC) is a medical school located in Albany, New York, United States.  It was founded in 1839 by Alden March and James H. Armsby and is one of the oldest medical schools in the nation.  The college is part of the Albany Medical Center, which includes the Albany Medical Center Hospital. Henry Hun. Henry Hun (March 21, 1854 – March 14, 1924) an American physician, was professor of Nervous Diseases at the Albany Medical College in New York for 30 years.  He published several unique teaching volumes for his students as well as numerous journal articles on neurological disorders. '

# %%
class MyDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 title_to_contexts,
                 support_facts_lists,
                 questions,
                 answers,
                 tokenizer,
                 config,
                 data_type):
        self.title_to_contexts=title_to_contexts
        self.support_facts_lists=support_facts_lists
        self.questions = questions
        self.answers=answers
        self.tokenizer = tokenizer
        self.config=config
        self.data_type=data_type

    def __len__(self):
        if self.data_type=='train':
            return self.config.epochs*self.config.training_batch*self.config.batch_size
        return len(self.answers)
    
    def __getitem__(self,item):
        if self.data_type=='train':
            title_to_context,question,answer,support_facts_list=get_example()
        else:
            title_to_context= self.title_to_contexts[item]
            support_facts_list=self.support_facts_lists[item]
            answer=self.answers[item]
            question=''
            if self.data_type=='dev':
                question=self.questions[item]

        context=get_context(title_to_context,
                            support_facts_list,
                            self.data_type,
                            self.config.pg_num)

        source=f'Please generate only one question according to the answer and the paragraphs.\n\
                   Answer: {answer} \n Content: {context}'
        target=question
            
        source_encoding = self.tokenizer(text=source,
                      max_length=self.config.max_source_length,
                      padding=True,
                      truncation=True,
                      add_special_tokens=True,
                      return_attention_mask=True,
                      )
        if self.data_type=='test':
            return {
                "input_ids":source_encoding['input_ids'],
               "attention_mask":source_encoding['attention_mask'],
               }
        
        target_encoding=self.tokenizer(text=target,
                      max_length=self.config.max_target_length,
                      padding=True,
                      truncation=True,
                      add_special_tokens=True,
                      return_attention_mask=True,
                    )
   

        return {
                "input_ids":torch.LongTensor(source_encoding['input_ids']),
                "attention_mask":torch.LongTensor(source_encoding['attention_mask']),
                "labels":torch.LongTensor(target_encoding['input_ids']),
               }

    
def create_data_loader(data_path,data_type,tokenizer,config,shuffle=True):
    pg_num=config.pg_num
    max_len=config.max_source_length
    if data_type=='train':
        batch_size=config.batch_size
        title_to_contexts=None
        questions=None
        answers=None
        support_facts=None
    else:
        title_to_contexts,questions,answers,support_facts=get_datas(data_path,data_type)
        batch_size=config.batch_size*2

    ds = MyDataSet(
                   title_to_contexts=title_to_contexts,
                   support_facts_lists=support_facts,
                   questions=questions,
                   answers=answers,
                   tokenizer = tokenizer,
                   config=config,
                   data_type=data_type
                  )
    
    collate_fn = DataCollatorForSeq2Seq(tokenizer, pad_to_multiple_of=8,padding=True)
    
    return torch.utils.data.DataLoader(ds,batch_size=batch_size,collate_fn=collate_fn,shuffle=shuffle)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
def load_model(model_name):
    print('model_name:',model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name,use_fast=True)
    model = ConditionalGeneration.from_pretrained(model_name,device_map="auto")#.to(device)
    print('Successfully loaded model')
    return model,tokenizer
def load_checkpoint(checkpoint):
    if checkpoint:
        try:
            model.load_state_dict(torch.load(checkpoint))
            print('Successfully loaded checkpoint!')
        except:
            print('Failed to load checkpoint!')
    


## 加载模型和检查点
model_name='t5-base'
checkpoint='/kaggle/input/t5-base-checkpoint5/checkpoint_best (34.90).pkl'
if model_name==None:
    model_name=args.defalut_model_name
model,tokenizer=load_model(model_name)
load_checkpoint(checkpoint)

optimizer = Adafactor(model.parameters(), relative_step=True, warmup_init=True,lr=None,clip_threshold=1.0)
scheduler = AdafactorSchedule(optimizer)
# Out:
# model_name: t5-base
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Successfully loaded model
# Failed to load checkpoint!

# %%
# %%time
## about 23s
def prepare_data(tokenizer,config):
    train_data_path=args.train_data_path
    dev_data_path=args.dev_data_path
    test_data_path=args.test_data_path
    print('preparing data...')
    train_data_loader=create_data_loader(train_data_path,'train',tokenizer,config,shuffle=True,)
    dev_data_loader=create_data_loader(dev_data_path,'dev',tokenizer,config,shuffle=False)
    test_data_loader=create_data_loader(test_data_path,'test',tokenizer,config,shuffle=False)
    print('prepare data success!')
    return train_data_loader,dev_data_loader,test_data_loader
train_data_loader,dev_data_loader,test_data_loader=prepare_data(tokenizer,config=get_eval_config())
# Out:
# preparing data...
# 1500it [00:00, 200735.63it/s]
# 7405it [00:00, 59629.88it/s]
# prepare data success!
# CPU times: user 1.03 s, sys: 593 ms, total: 1.62 s
# Wall time: 2.93 s

# %%
train_generator=get_infinite_data(train_data_loader)
def get_batch():
    return train_generator.__next__()
def get_answer(batch):
    bad_answers=[]
    for i in range(batch['input_ids'].shape[0]):
        bad_answers.append(tokenizer.convert_ids_to_tokens(batch['input_ids'][i])[10:20])
    return bad_answers
x=get_batch()
inputs=tokenizer.convert_ids_to_tokens(x['input_ids'][0])
#labels=tokenizer.convert_ids_to_tokens(x['labels'][0].reshape(-1))
x['input_ids'].shape,inputs

# %%
## 评估模型函数
def eval_model(epoch=1,testing_batch=-1):
    model.eval()
    preds_list = []
    real_list=[]
    if testing_batch<=0:
        testing_batch=len(dev_data_loader)
    with tqdm(total=testing_batch, desc=f'Validation Epoch {epoch}', unit='batch') as pbar:
        for i,batch in enumerate(dev_data_loader):
            if i>testing_batch:break
            with torch.no_grad():
                input_ids = batch['input_ids'].to(device)
                attention_mask=batch['attention_mask'].to(device)
                labels=batch['labels'].to(device)
                if hasattr(torch.cuda, 'empty_cache'):
                    torch.cuda.empty_cache()
                generated_ids = model.generate(
                    input_ids=input_ids, 
                    attention_mask=attention_mask,
                    do_sample=False,
                    max_new_tokens=128,
                    num_beams=3, 
                )
                preds_list.extend(tokenizer.batch_decode(generated_ids, skip_special_tokens=True))
                labels=torch.where(labels!=-100,labels,tokenizer.pad_token_id)
                real_list.extend(tokenizer.batch_decode(labels, skip_special_tokens=True))
                
            pbar.update(1)
    
    scores,all_score = getTotalScore(preds_list, real_list)
    for i in range(20):
        print('pred: ',preds_list[i])
        print("true: ",real_list[i])
        print('bleu4:',all_score[i])

    if scores['TotalScore'] > logging.best_score:
        torch.save(model.state_dict(),  "/kaggle/working/checkpoint_best.pkl")
        print(f"Total score: {logging.best_score} -> {scores['TotalScore'] }")
        print(f"checkpoint_best.pkl已存储至/kaggle/working/")
        logging.best_score = scores['TotalScore'] 

    logging.scores_list.append(scores)
    print(f"Scores: {scores}")
    return preds_list
pred_list=eval_model(epoch=0,testing_batch=10)

# %%
def train(model,config,show=False):
    if show:
        show_config(config)
        
    pg_num=config.pg_num
    training_batch=config.training_batch
    testing_batch=config.testing_batch
    updata_batch=config.updata_batch
    epochs=config.epochs
    global dev_data_loader
    train_data_loader,dev_data_loader,_=prepare_data(tokenizer,config)
    train_generator=get_infinite_data(train_data_loader)
    def get_batch():
        return train_generator.__next__()
    
    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        batch_loss=0
        with tqdm(total=training_batch//updata_batch, desc=f'Epoch {epoch + 1}/{epochs}', unit='batch',mininterval=3) as pbar:
            for i in range(training_batch):
                batch=get_batch()
                input_ids= batch['input_ids'].to(device)
                attention_mask=batch['attention_mask'].to(device)
                labels=batch['labels'].to(device)
 
                if hasattr(torch.cuda, 'empty_cache'):
                    torch.cuda.empty_cache()

                outputs = model(
                                input_ids=input_ids,
                                attention_mask=attention_mask,
                                labels=labels, 
                                return_dict=True,
                               )
                
               
                loss = outputs.loss
                loss.backward() 

                loss_t = loss.detach().cpu()
                epoch_loss += loss_t[0] if len(loss_t.shape) > 0 else loss_t.numpy()
                batch_loss +=loss_t[0] if len(loss_t.shape) > 0 else loss_t.numpy()
                
                if (i+1)%updata_batch==0:
                    optimizer.step()
                    scheduler.step()
                    optimizer.zero_grad()
                    batch_loss=batch_loss/updata_batch
                    #lr=optimizer.param_groups[0]['lr']
                    logging.loss_list.append(batch_loss)
                    pbar.set_postfix({
                        'loss': f'{ batch_loss:.4f}',
                        #'lr':f'{lr:.6f}'
                    })
                    batch_loss=0
                    pbar.update(1)
                    
        print(f"Average Loss: {epoch_loss / training_batch:.4f}")
        # 验证部分
        if config.eval_model:
            eval_model(epoch,testing_batch)
        torch.save(model.state_dict(), "/kaggle/working/checkpoint_last.pkl")

# %%
## stage1
config1={
    'pg_num':2,
    'max_source_length':384,
    'batch_size':12,
    'updata_batch':2,
    'epochs':10,
}
trainer_config=get_trainer_config(**config1)
train(model,trainer_config,True)
# Out:
# pg_num: 2
# max_souce_length: 384
# train_batch: 512
# updata_batch: 2
# epochs: 10
# batch_size: 12
# preparing data...
# 1500it [00:00, 137913.06it/s]
# 7405it [00:00, 56261.29it/s]
# prepare data success!
# Epoch 1/10: 100%|██████████| 256/256 [11:04<00:00,  2.60s/batch, loss=1.6687]
# Average Loss: 2.0888
# Validation Epoch 0: 11batch [01:21,  7.37s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.82 seconds, 107.81 sentences/sec
# {'testlen': 1329, 'reflen': 1534, 'guess': [1329, 1241, 1153, 1065], 'correct': [295, 84, 29, 11]}
# ratio: 0.8663624511076491
# pred:  Plantago is a genus of about 200 species of small, inconspicuous plants commonly called plantains or fleaworts. Plantago princeps is a rare species of flowering plant in the plantain family known by the common name ale.
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 4.9687989121574917e-14
# pred:  What season of the Indian reality TV series "Bigg Boss" was hosted by Salman Khan?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.2928298013524784
# pred:  Which United States Senator was elected to the open seat left vacant by resigning U.S. Senator John Ensign?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.284411468590456e-09
# pred:  The episode that was the first episode to air in the 1980s was the one that was originally the eighth episode produced for season one?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 1.6414436041797558e-09
# pred:  What is the name of the band that featured in the film "Robin Hood"?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 7.378223692772331e-17
# pred:  What author was the guest of honor at the annual science fiction convention?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 3.667625609921808e-09
# pred:  Which brewery was founded by which woman?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 3.446913316568276e-13
# pred:  The structure of Liberty is a book by a legal theorist which offers a libertarian theory of law and politics.
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 2.0646212119418024e-09
# pred:  What county is the county that has the largest sheriff's office in existence?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 4.701523684437746e-13
# pred:  Which city is home to the liquor brand of the Nolet Distillery?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 7.069301148368759e-13
# pred:  Brenda VanLengen is the primary analyst for the Big 12 Conference women's basketball game of the week on Fox Sports 1 and the San Antonio Silver Stars on Fox Sports Southwest?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 1.68578071194333e-09
# pred:  The 2017 Ladies Open Biel Bienne was a women's tennis tournament played on indoor hard courts.
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 6.953621720357608e-17
# pred:  What is the name of the ancient Greek mathematician who created the axiom of the axiom of Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 2.945274365311036e-09
# pred:  What film was produced by the same artist who created the character "Casper"?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 3.435094189227651e-13
# pred:  What is the name of the opera "Werther Quartet" that was written in response to the enormous success of the novel "The Sorrows of Young Werther"?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 1.23063955591741e-17
# pred:  What film was written and directed by Richard Curtis and starred a Scottish comedian and actor?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.6628208413987833e-13
# pred:  What city is the college of the former wide receiver who played for the Seattle Seahawks, the San Francisco 49ers and the Denver Broncos of the NFL?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 1.3310179952546751e-09
# pred:  What city is the headquarters of the American regional airline that was sold to a company that was a subsidiary of the company that Timothy E. Hoeksema was the chairman of?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.5463207785866462e-09
# pred:  What part of the country is the SETsquared Partnership that produced and distributed pub quizzes?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 6.511259555447858e-17
# pred:  What year did the father of the physicist who developed the theory of relativity receive the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 1.989810734296456e-05
# Total score: 0 -> 12.061975266614335
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 12.061975266614335, 'BERTScore': 0.20314489099705083, 'Bleu1': 0.19024205971779085, 'Bleu2': 0.10505380188530668, 'Bleu3': 0.06196321086980384, 'Bleu4': 0.038094614335235866}
# Epoch 2/10: 100%|██████████| 256/256 [11:08<00:00,  2.61s/batch, loss=1.5812]
# Average Loss: 1.4212
# Validation Epoch 1: 11batch [01:15,  6.90s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.81 seconds, 109.21 sentences/sec
# {'testlen': 1329, 'reflen': 1496, 'guess': [1329, 1241, 1153, 1065], 'correct': [360, 110, 47, 20]}
# ratio: 0.8883689839566254
# pred:  Are Plantago and Plantago hawaiensis both species of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 6.376715692219053e-09
# pred:  What season of the Indian reality TV series "Bigg Boss" was hosted by Salman Khan?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.2928298013524784
# pred:  Which Nevada senator was elected to the open seat left vacant by resigning U.S. Senator John Ensign?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 3.4159919055542935e-13
# pred:  The homer they fall was the first episode to air on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 3.636227045901134e-09
# pred:  Are Gene and Nigel Eaton both members of the same band?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 8.537431783425115e-13
# pred:  Which author was born first, Leonard Borgzinner or Samuel Ray Delany Jr?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 7.088856800987232e-13
# pred:  What was the name of the founder of the brewery that was purchased by the Browar oma?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 0.26243102771698756
# pred:  The structure of Liberty is a book by a legal theorist who offers a libertarian theory of law and politics?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 2.0646212119418024e-09
# pred:  The Baltimore County Sheriff's Office is located in what state?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 4.574636153375811e-09
# pred:  The Dutch billionaire who owns the Dutch liquor brand of the Nolet Distillery has a headquarters in what city?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 4.946195871594794e-13
# pred:  What is the name of the primary analyst for the Big 12 Conference women's basketball game of the week on Fox Sports 1?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 2.7793825175169742e-09
# pred:  What Swiss luxury watchmaker based in Biel/Bienne, Switzerland, has been the official timekeeping device of the Olympic Games since 1932?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 3.1346893678858016e-09
# pred:  What is the name of the city that is the birthplace of the preeminent mathematician and engineer who was born in the 8th century BC?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.1248757525050138
# pred:  What film was produced by the artist who created the character "Baby Felix"?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 3.435094189227651e-13
# pred:  Are the lyrics of the opera "Werther Quartet" and the novel "Odysseia" attributed to Homer?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 3.9614221585067024e-13
# pred:  What film did the actor who played the role of Rick Grimes in the Scottish comedy sketch show "Rab C. Nesbitt" have in common?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 2.166009738015042e-13
# pred:  Where is the university where Dexter Jackson played college football located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.5783569865957396
# pred:  Where is the company that owns the airline that Timothy E. Hoeksema transformed the air fleet of the Kimberly Clark paper mill company?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 3.9194224237857213e-13
# pred:  What part of the country is the English language spoken in the West Derby Hundred?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 3.6615503270688734e-13
# pred:  What year did the physicist who was the father of the cosmic catastrophe win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 1.8107197868889782e-05
# Total score: 12.061975266614335 -> 15.497143771898402
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 15.497143771898402, 'BERTScore': 0.2521979140583426, 'Bleu1': 0.23889374272213473, 'Bleu2': 0.13665529576868243, 'Bleu3': 0.0875621156048412, 'Bleu4': 0.05774496137962548}
# Epoch 3/10: 100%|██████████| 256/256 [11:08<00:00,  2.61s/batch, loss=1.2998]
# Average Loss: 1.3044
# Validation Epoch 2: 11batch [01:09,  6.34s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.74 seconds, 118.60 sentences/sec
# {'testlen': 1329, 'reflen': 1387, 'guess': [1329, 1241, 1153, 1065], 'correct': [394, 128, 53, 24]}
# ratio: 0.9581831290548247
# pred:  Are Plantago and Plantago hawaiensis both endemic to Hawaii?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 6.030725358915047e-09
# pred:  What season of the Indian reality TV series "Bigg Boss" was hosted by Salman Khan?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.2928298013524784
# pred:  Which Republican U.S. Senator from Nevada was elected to the open seat left vacant by resigning U.S. Senator John Ensign?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 3.6351253345722926e-13
# pred:  When did the episode that was the first episode to air on the Fox network in the United States?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 2.725617347054086e-09
# pred:  Are both Nigel Eaton and Jeff Mueller members of the band that was formed in the fall of 1996?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 2.922793147762758e-13
# pred:  Which author was born first, Leonard Borgzinner or Samuel Ray Delany?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 6.40550520920913e-13
# pred:  Who founded the brewery that was purchased by the brewery that was the largest brewery in the Cole-Noble District of Indianapolis?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 0.18931747781103497
# pred:  What is the political philosophy of the city where the Liberty Hill Historic District is located?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 5.180010910448989e-13
# pred:  What state has a sheriff's office that serves the community that was part of the Lutherville-Timonium CDP?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 2.851618261976597e-13
# pred:  Where is the liquor brand of the Nolet Distillery in which Bart le Blanc is the chairman of?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 2.1467651087720975e-05
# pred:  Which analyst for the Big 12 Conference women's basketball game of the week on Fox Sports 1 and the San Antonio Silver Stars on Fox Sports Southwest is the primary analyst for the Kansas Jayhawks women's basketball team?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 0.1041998433784185
# pred:  What Swiss luxury watchmaker based in Biel/Bienne, Switzerland, is the official timekeeper of the Olympic Games?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 4.70723505087029e-09
# pred:  What is the name of the city that is the birthplace of the preeminent mathematician and engineer who was born in the 8th century?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.1282024574333395
# pred:  What movie was produced by the artist who created the character "Casper"?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 3.435094189227651e-13
# pred:  Are the Sorrows of Werther and Odyssey both operas?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 7.849573143826273e-09
# pred:  Which film was written and directed by Richard Curtis and starred a Scottish comedian and actor?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 6.513518884920897e-17
# pred:  Where is the college where Greg Jackson played for the Dallas Cowboys located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 3.695372083495759e-05
# pred:  Where is the American airline holding corporation that owns the airline that Timothy E. Hoeksema transformed the air fleet of the Kimberly Clark paper mill company into?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 3.2089516726568125e-13
# pred:  What country does the English language in southern England belong to?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 7.179095782155307e-13
# pred:  In what year did the man who was born in 1879 receive the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 1.8107197869842796e-05
# Total score: 15.497143771898402 -> 17.330392124445755
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 17.330392124445755, 'BERTScore': 0.2747910511256619, 'Bleu1': 0.28380355571628607, 'Bleu2': 0.16739840127204483, 'Bleu3': 0.10723385573584386, 'Bleu4': 0.07181679136325325}
# Epoch 4/10: 100%|██████████| 256/256 [11:04<00:00,  2.60s/batch, loss=1.2828]
# Average Loss: 1.2477
# Validation Epoch 3: 11batch [01:08,  6.21s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.79 seconds, 111.58 sentences/sec
# {'testlen': 1329, 'reflen': 1488, 'guess': [1329, 1241, 1153, 1065], 'correct': [388, 122, 44, 20]}
# ratio: 0.8931451612897223
# pred:  Are both Plantago and Plantago hawaiensis native to the same country?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 4.82902736160217e-09
# pred:  What season of the Indian reality TV series "Bigg Boss" did Lopamudra Raut win the third "Best National Costume" award for India?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.2496907208867028
# pred:  Who was the senior United States Senator from Nevada who was elected to the open U.S. Senate seat in 2012?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.570421774539086e-09
# pred:  When did the episode in which the character who manages the bar in Fort Greene, Brooklyn first air?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 2.8123983919155253e-09
# pred:  Are both Jeff Mueller and Gene from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 5.4401898621431946e-09
# pred:  Who is the American author, professor and literary critic who has been a guest of honor at Readercon?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 1.6169122874795358e-05
# pred:  Who founded the brewery that was the largest in the United States, ywiec Brewery or Frederick Brewing Company?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 0.1392908359880505
# pred:  What is the meaning of the philosophies that are used to determine if a type is equivalent and whether a subtype of another is considered to be?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 1.8231997290956044e-13
# pred:  The Baltimore County Sheriff's Office is located in what state?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 4.574636153375811e-09
# pred:  Where is the liquor brand of the Nolet Distillery in which the Dutch billionaire who was the chairman of the company that has its headquarters in the CBS Building, located?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 1.1157778727921504e-05
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball team that was coached by Bonnie Henrickson?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 3.735229177830252e-09
# pred:  Joseph Reiser was a longtime general manager of which Swiss luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.547001422295134e-05
# pred:  Montes Archimedes is a mountain range on the Moon, which is the capital of what province in the autonomous island region of Sicily in Italy?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 2.0665381834753236e-09
# pred:  What movie was the creator of the character "Casper the Friendly Ghost" with the help of the actress who played Toaster in the film "The Brave Little Toaster"?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 2.0697425285997033e-13
# pred:  Are both the Piano Quartet No. 3 and the Opera "The Odyssey" based on the same novel?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 3.2945022128220503e-13
# pred:  What film did the actor who played Rick Grimes in the show "Scotch and Wry" also have in common?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.2268949768114413e-13
# pred:  Where is the university located where the former football player who played for the Seattle Seahawks, the San Francisco 49ers and the Denver Broncos of the NFL played?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 9.121304894716814e-06
# pred:  Where is the headquarters of the company that sold the company that was the chairman of the Kimberly Clark paper mill company to the company that is headquartered?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 2.8868282677738243e-13
# pred:  Where is the English language spoken in southern England, which is the collective set of dialects and accents of the English spoken in southern England, located?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 1.1009499956489937e-13
# pred:  When did the physicist who was the first Pakistani to win a Nobel Prize in science win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.11977165748993263
# Scores: {'TotalScore': 15.364154663716334, 'BERTScore': 0.24753264667974276, 'Bleu1': 0.259028924664567, 'Bleu2': 0.15031035997329684, 'Bleu3': 0.0914564287940494, 'Bleu4': 0.059750446594583895}
# Epoch 5/10: 100%|██████████| 256/256 [11:05<00:00,  2.60s/batch, loss=1.1920]
# Average Loss: 1.2218
# Validation Epoch 4: 11batch [01:28,  8.01s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 1.13 seconds, 77.61 sentences/sec
# {'testlen': 1329, 'reflen': 1496, 'guess': [1329, 1241, 1153, 1065], 'correct': [406, 134, 52, 20]}
# ratio: 0.8883689839566254
# pred:  Are both Plantago and Plantago hawaiensis genuses of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 6.376715692219053e-09
# pred:  What season of Indian reality TV series did Lopamudra Raut compete in?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.4623953023675646e-05
# pred:  Which Republican Senator was elected to the open seat in the United States Senate in Nevada in 2012?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.225025328784018e-05
# pred:  When did the Simpsons episode that aired in the United States air?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 7.347053125332871e-13
# pred:  Are both Jeff Mueller and Jason Noble members of the same American post-rock/post-hardcore band?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 5.460496482718372e-13
# pred:  Which American author has been a guest of honor at the annual science fiction convention, Readercon?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 2.8563496970198435e-09
# pred:  Who founded the brewery that was purchased by the largest brewery in the United States?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 0.17059573700821185
# pred:  What is the main difference between the structure of Liberty Place and the structure of Liberty?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 3.080052915248831e-09
# pred:  What state is the county where Towson High School is located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 6.036875907977461e-13
# pred:  Where is the company that has the most shares in the company, Vermeer Corporation or Freddy Heineken, located?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 3.3943336725494714e-09
# pred:  Which team has been coached by Brandon Schneider, the team that won the NCAA championship in the 2009-10 season?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 3.2247728382115003e-13
# pred:  What Swiss luxury watchmaker based in Biel/Bienne, Switzerland, is the official timekeeping device of the Olympic Games?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 4.403651270274819e-09
# pred:  Montes Archimedes is a mountain range on the Moon, which is the capital of which autonomous island region of Sicily?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 4.020443440017966e-13
# pred:  What movie did the creator of the animated series "Animaniacs" write?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 2.888558389780397e-13
# pred:  Are both the operas "Werther Quartet" and "Odyssey" based on the same novel?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 5.833887889251737e-13
# pred:  What film did Gregor Fisher play in that was released on Region 1 DVD in 2006?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 1.9479965052055742e-05
# pred:  Where is the college where Dexter Jackson played college football located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.670342089576329
# pred:  Where is the company that Timothy E. Hoeksema was the chairman of headquartered?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 4.30664170792929e-13
# pred:  What part of England does the English language in southern England belong to?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.591085416887175e-13
# pred:  In what year did the German-born theoretical physicist who saw a deficiency in Newton's theory win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 2.089185388853242e-05
# Scores: {'TotalScore': 16.747332732285997, 'BERTScore': 0.2708294797868637, 'Bleu1': 0.26941905429218527, 'Bleu2': 0.16017483654248482, 'Bleu3': 0.10067692832648058, 'Bleu4': 0.06411717485885618}
# Epoch 6/10: 100%|██████████| 256/256 [11:07<00:00,  2.61s/batch, loss=1.4339]
# Average Loss: 1.2004
# Validation Epoch 5: 11batch [01:33,  8.50s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 1.18 seconds, 74.64 sentences/sec
# {'testlen': 1329, 'reflen': 1615, 'guess': [1329, 1241, 1153, 1065], 'correct': [439, 164, 66, 26]}
# ratio: 0.8229102167177568
# pred:  Are Plantago and Plantago both types of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 4.264366797236323e-05
# pred:  What season of the Indian reality TV series "Bigg Boss" did Lopamudra Raut win the third Best National Costume Award for India?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.2496907208867028
# pred:  United States Senate election in Wyoming, 2012 and the 2012 United States Senate election in Utah, 2012 were held alongside which other election to the United States Senate and House of Representatives?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 0.1263410722664223
# pred:  When was the first episode of the Simpsons that featured the character "Moe" first aired?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 2.9485531032573552e-05
# pred:  Are both Jeff Mueller and Gene from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 5.4401898621431946e-09
# pred:  Which author has been a guest of honor at the annual science fiction convention, Harlan Coben or Leonard Borgzinner?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 2.527551091262214e-09
# pred:  Who founded the brewery that purchased the Browar oma brewery?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 1.4728212723437737e-05
# pred:  What type of philosophy does the structure of Liberty and the structure of Liberty have in common?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 2.0625716459053316e-05
# pred:  What country is the county that has a historic district that includes the town of Towson High School?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 2.5165442835480144e-13
# pred:  In what city is the liquor brand of which Bart le Blanc is the chairman?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 3.7013098954741056e-09
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball team that played their home games at Allen Fieldhouse in Lawrence, Kansas?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 2.7327520441981274e-09
# pred:  What Swiss luxury watchmaker based in Biel/Bienne, Switzerland is the official timekeeper of the Olympic Games?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 4.70723505087029e-09
# pred:  What is the name of the city that is the birthplace of the Greek mathematician who is a triskelion?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.14576846148119033
# pred:  What movie did the writer of "My Favorite Martian" work with?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 3.435094189227651e-13
# pred:  Are the lyrics of the song "Werther Quartet" and "The Sorrows of Werther" both written by the same person?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 2.4757436049220553e-13
# pred:  Gregor Fisher has had a role in what 2003 Christmas-themed romantic comedy film written and directed by Richard Curtis?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 0.12700991969246436
# pred:  Where is the university where Dexter Jackson played college football located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.5783569865957396
# pred:  Where is the American airline holding corporation based that sold the company that was formerly known as Midwest Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 4.553719183899022e-13
# pred:  In what country is the English language spoken in southern England, which is a collective set of different dialects and accents of the English spoken in southern England, found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 7.566711284945205e-14
# pred:  In what year did the man who saw a deficiency in Isaac Newton's classical theory of gravity win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.2223715948385177
# Total score: 17.330392124445755 -> 18.75566094466963
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 18.75566094466963, 'BERTScore': 0.3038480067169241, 'Bleu1': 0.2663665147275964, 'Bleu2': 0.168479044896673, 'Bleu3': 0.10942473418215147, 'Bleu4': 0.07126521217646849}
# Epoch 7/10: 100%|██████████| 256/256 [11:08<00:00,  2.61s/batch, loss=1.2209]
# Average Loss: 1.1775
# Validation Epoch 6: 11batch [01:18,  7.17s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.87 seconds, 101.25 sentences/sec
# {'testlen': 1329, 'reflen': 1416, 'guess': [1329, 1241, 1153, 1065], 'correct': [403, 139, 58, 23]}
# ratio: 0.9385593220332354
# pred:  Are both Plantago and Plantago a rare species of flowering plant?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 5.10607476252634e-09
# pred:  What season of the Indian reality TV series "Bigg Boss" did Lopamudra Raut win the title of Miss United Continents 2016?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.26481899767115935
# pred:  What senior United States Senator from Nevada was recently appointed to the seat left vacant by resigning U.S. Senator John Ensign?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.1400047283729616e-09
# pred:  What date did the episode that starred in the episode "Flaming Moe's" air?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 6.94841384364963e-13
# pred:  Are both Jeff Mueller and Gene from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 5.4401898621431946e-09
# pred:  Which American author, professor and literary critic has had guest of honors at the Readercon?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 4.194906345202033e-13
# pred:  Who founded the brewery that was purchased by the Browar oma?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 0.12740810459729404
# pred:  What kind of philosophies are the Liberty Hill Historic District and the Libertarianism?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 6.5070528624819e-13
# pred:  What state is the county that Towson High School is located in?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 5.327524290077678e-13
# pred:  What is the name of the distillery that has a liquor brand that is owned by the Dutch businessman who bought Heineken International?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 1.9970634411862727e-09
# pred:  What analyst for the Kansas Jayhawks women's basketball team played their home games at Allen Fieldhouse in Lawrence, Kansas?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 0.2717107124811884
# pred:  What Swiss luxury watchmaker based in Biel/Bienne, Switzerland, was the architect of the worldwide brand notoriety?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 4.092666651528717e-09
# pred:  What is the name of the city that is the birthplace of the preeminent mathematician and engineer?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.14576846148886236
# pred:  What movie did the writer of the voice of Toaster work on with the creator of the character in the movie "Reform School Girls"?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 3.541229552229043e-13
# pred:  Are the lyrics of the Piano Quartet No. 3 and the novel "The Sorrows of Werther" both attributed to Homer?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 2.146167416554774e-13
# pred:  What 2003 Christmas-themed romantic comedy film did Gregor Fisher play in?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 0.48959148316822143
# pred:  Where is the college that both Dexter Jackson and Darrell Jackson played for located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 3.421770720418436e-05
# pred:  What city is the company that sold the Kimberly Clark paper mill company to the company that is headquartered in?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 4.0077816996103734e-13
# pred:  What part of England is the SETsquared Partnership located?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 1.3784336587052549e-16
# pred:  What year did the father of the man who saw a deficiency in Newton's theory win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 2.0285646317188276e-05
# Scores: {'TotalScore': 18.402329418304383, 'BERTScore': 0.2950470881451937, 'Bleu1': 0.2840206731415081, 'Bleu2': 0.1726161512760584, 'Bleu3': 0.1119722685990521, 'Bleu4': 0.07299950022089398}
# Epoch 8/10: 100%|██████████| 256/256 [11:08<00:00,  2.61s/batch, loss=1.3926]
# Average Loss: 1.1588
# Validation Epoch 7: 11batch [01:07,  6.13s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.72 seconds, 121.54 sentences/sec
# {'testlen': 1329, 'reflen': 1339, 'guess': [1329, 1241, 1153, 1065], 'correct': [442, 165, 78, 40]}
# ratio: 0.9925317401038144
# pred:  Are Plantago asiatica and Plantago hawaiensis both flowering plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 6.030725358915047e-09
# pred:  What season of the Indian reality TV series "Bigg Boss" did Lopamudra Raut win the "Best National Costume" award for India?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 0.26481899767115935
# pred:  Which United States Senator from Nevada was elected to Nevada's open U.S. Senate seat in 2012?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.8724953479163113e-09
# pred:  When did the Simpsons episode that aired "The Homer They Fall" originally air?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 6.94841384364963e-13
# pred:  Are both the shipping news and the band "Gene" from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 6.18755314236917e-13
# pred:  Who is the author of the seminal Afrofuturistic works of the author who was a guest of honor at Readercon?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 1.3686867021025061e-05
# pred:  Who founded the brewery that sold Marble Brewery to the United States?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 1.4728212723437737e-05
# pred:  What type of movement does the structure of liberty and the structure of liberty have in common?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 1.7626201281132848e-05
# pred:  What state is the county in which Towson High School is located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 5.327524290077678e-13
# pred:  Where is the company that Carolus Nolet is chairman of located?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 3.2857020445327865e-05
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game of the week on Fox Sports 1 and the San Antonio Silver Stars on Fox Sports Southwest?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 1.878191181571486e-09
# pred:  What Swiss luxury watchmaker based in Biel/Bienne was the general manager of the company that made the first edition of the Ladies Open Biel Bienne?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 1.2630765830909406e-05
# pred:  What province in Sicily is the capital of?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 4.237713199509635e-13
# pred:  What movie did the creator of the character "Casper the Friendly Ghost" work with Sherri Stoner?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 4.085038450534026e-13
# pred:  Were Werther and Odyssey both written by Jules Massenet?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 7.423667935030377e-09
# pred:  What 2003 Christmas-themed romantic comedy film did Gregor Fisher star in?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 0.48959148316822143
# pred:  Where is the university where Dexter Jackson played college football located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.5783569865957396
# pred:  Where is the headquarters of the company that sold the company that transformed the air fleet of the Kimberly Clark paper mill company into Midwest Air Group?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 3.0348391181118864e-13
# pred:  Where is the SETsquared Partnership located?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 1.5619699682123511e-16
# pred:  In what year did the father of the man who saw a deficiency in Newton's theory win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 1.9820717676246736e-05
# Total score: 18.75566094466963 -> 21.222044304088588
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 21.222044304088588, 'BERTScore': 0.3222579320956191, 'Bleu1': 0.3300877894996743, 'Bleu2': 0.20870694282372387, 'Bleu3': 0.14300693095905678, 'Bleu4': 0.1021829539861527}
# Epoch 9/10: 100%|██████████| 256/256 [11:12<00:00,  2.63s/batch, loss=1.1154]
# Average Loss: 1.1353
# Validation Epoch 8: 11batch [01:28,  8.02s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 1.23 seconds, 71.51 sentences/sec
# {'testlen': 1329, 'reflen': 1565, 'guess': [1329, 1241, 1153, 1065], 'correct': [432, 146, 54, 20]}
# ratio: 0.849201277954729
# pred:  Are Plantago hawaiensis and Plantago a genus of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 6.030725358915047e-09
# pred:  What season of Bigg Boss was hosted by Salman Khan?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.4325425696936665e-09
# pred:  Which United States Senator from Nevada was elected to the Senate in 2012, United States Senate election in Utah, 2012, or United States Senate election in Nevada, 2012, alongside 33 other elections to the United States Senate in other states, as well as other elections to the United States Senate in other states, as well as other elections to the United States Senate in other states, as well as other elections to the United States Senate in other states, as well as other elections to the United States Senate and House of Representatives, as well as other elections to the United States
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 0.001978790759813174
# pred:  When did the Simpsons episode in which Morris "Moe" Szyslak appeared air?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 4.131551590743584e-09
# pred:  Are the bands that Nigel Eaton worked with in the post-rock/post-hardcore band TradeWinds?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 4.701523684437746e-13
# pred:  Which American author, professor and literary critic, who was a guest of honor at the annual science fiction convention, held every July in the Boston, Massachusetts area, in the mid-1980s, also wrote books about the extraterrestrial mythoi of Parliament-Funkadelic, the Jonzun Crew, Warp 9, and Sun Ra?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 2.1571679768101577e-10
# pred:  Who founded the brewery that was the largest brewery in the United States in 2006?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 0.17059573700821185
# pred:  What type of political philosophies and movements are the Liberty Hill Historic District and The Structure of Liberty?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 2.594201983307682e-05
# pred:  What state is the county that Towson High School is located in?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 5.327524290077678e-13
# pred:  In what city is the company that has a headquarters named after a copper pot still?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 3.292600974421402e-09
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game of the week on Fox Sports 1 and the San Antonio Silver Stars on Fox Sports Southwest?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 1.878191181571486e-09
# pred:  What luxury watchmaker based in Biel/Bienne, Switzerland, was the first edition of the Ladies Open Biel Bienne?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 3.828718239911076e-09
# pred:  What is the name of the autonomous island region of Sicily in Italy, which has a historic city named after the 3rd century BC Greek mathematician?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 2.0376168683221627e-09
# pred:  What movie was produced by the author of over 80 children's books and also starred Christina Ricci, Bill Pullman, Cathy Moriarty, Etienned, Sybil Danning, Sybil Danning, Sybil Danning, and Sherri Stoner?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 1.4268859200510966e-09
# pred:  Were the opera Werther and the poem The Odyssey both written by William Makepeace Thackeray?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 2.0730818165298196e-05
# pred:  What film written and directed by Richard Curtis did Gregor Fisher star in?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 2.780379138071938e-05
# pred:  Where was the college where Dexter Jackson played college football located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.5914601686329329
# pred:  Where is the American airline holding corporation based that sold the Kimberly Clark paper mill company to Timothy E. Hoeksema?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 4.306641707713958e-13
# pred:  Where is the English language spoken in southern England?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.736753415588487e-09
# pred:  In what year did the man who saw a deficiency in Newton's theory of gravity receive his Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 2.898251296465216e-05
# Scores: {'TotalScore': 18.80970702115798, 'BERTScore': 0.31243016226322984, 'Bleu1': 0.272168587928076, 'Bleu2': 0.16373787669750398, 'Bleu3': 0.10168276138338025, 'Bleu4': 0.06376397815992974}
# Epoch 10/10: 100%|██████████| 256/256 [11:05<00:00,  2.60s/batch, loss=1.2723]
# Average Loss: 1.1160
# Validation Epoch 9: 11batch [01:14,  6.77s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/3 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 0.82 seconds, 107.69 sentences/sec
# {'testlen': 1329, 'reflen': 1391, 'guess': [1329, 1241, 1153, 1065], 'correct': [428, 148, 62, 25]}
# ratio: 0.9554277498195863
# pred:  Are both plantago and plantago asiatica plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 9.980099402512292e-13
# pred:  What season of Indian reality TV series "Bigg Boss" did Lopamudra Raut contest?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.735838424446947e-05
# pred:  Which senior United States Senator from Nevada was elected to his first full term in the United States Senate election in Wyoming, 2012?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 0.15939331383660452
# pred:  When was the episode of "The Simpsons" that the character who manages Moe Goes from Rags to Riches first appeared?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 1.941219422264679e-05
# pred:  Are both Nigel Eaton and Jeff Mueller in the post-rock/post-hardcore band?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 7.944975501908116e-13
# pred:  Which author of Afrofuturism was born in 1942?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 9.578464407697051e-17
# pred:  Who founded the brewery that purchased Marble Brewery in 2006?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 1.4728212723437737e-05
# pred:  What type of political movement does the book "The Structure of Liberty" and the book "Libertarians" have in common?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 1.6886908369293644e-05
# pred:  What state is the city where Towson High School is located located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 5.327524290077678e-13
# pred:  Where is the liquor brand of the company that is owned by Bart Le Blanc located?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 3.292600974421402e-09
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball team that finished their season with a record of 0–18 in Big 12 play to finish in ninth place?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 1.8337202856245016e-09
# pred:  Which luxury watchmaker based in Biel/Bienne, Switzerland, is credited as the architect of the worldwide brand notoriety?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 3.828718239911076e-09
# pred:  Which province in the autonomous island region of Sicily in Italy is the Archimedean spiral named after?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 2.70765762660009e-09
# pred:  What movie was written by the creator of the character that is based on a cartoon series by John L. Greene?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.12582205557212853
# pred:  Are both the "Odyssey" and "Werther Quartet" written by William Render?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 7.763225772767659e-13
# pred:  Which film was Andrew Lincoln in that was filmed on location in London?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 8.7923308351231e-17
# pred:  Where is the college where Dexter Jackson played college football located?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.670342089576329
# pred:  Where is the headquarters of the company that sold the company that was formerly called Midwest Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 4.30664170792929e-13
# pred:  Where is the township of West Derby located?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 1.561969968017105e-16
# pred:  In what year did the man who saw a deficiency in Isaac Newton's theory of gravity receive the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 2.6004645109281143e-05
# Scores: {'TotalScore': 19.76047602607987, 'BERTScore': 0.3155697800473056, 'Bleu1': 0.30736771454734513, 'Bleu2': 0.18704401695404457, 'Bleu3': 0.12154296535900856, 'Bleu4': 0.07963974047429179}

# %%
## stage2
config2={
    'pg_num':7,
    'max_source_length':1024,
    'batch_size':4,
    'updata_batch':8,
    'epochs':20,
}
trainer_config=get_trainer_config(**config2)
train(model,trainer_config,True)
# Out:
# pg_num: 7
# max_souce_length: 1024
# train_batch: 512
# updata_batch: 8
# epochs: 20
# batch_size: 4
# preparing data...
# 1500it [00:00, 157046.90it/s]
# 7405it [00:00, 61402.31it/s]
# prepare data success!
# Epoch 1/20: 100%|██████████| 64/64 [11:57<00:00, 11.22s/batch, loss=1.0425]
# Average Loss: 1.0679
# Validation Epoch 0: 11batch [01:47,  9.81s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.52 seconds, 83.97 sentences/sec
# {'testlen': 635, 'reflen': 729, 'guess': [635, 591, 547, 503], 'correct': [284, 132, 64, 29]}
# ratio: 0.8710562414254169
# pred:  Are Plantago and Trichosanthes in the same genus?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 1.0724314734549807e-12
# pred:  Lopamudra Raut was a contestant of what season of Indian reality TV series "Bigg Boss"?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.3693055762206496e-05
# pred:  Which Republican U.S. Senator from Nevada was narrowly elected to his first full term in the 2012 United States Senate election?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 0.13090213860020217
# pred:  Moe Szyslak first appeared in an episode that originally aired on the Fox network in the United States on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 3.7551521143520844e-13
# pred:  Are the bands The Shipping News and Gene from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 0.22172045041645957
# pred:  Which American author is also a science fiction author, Harlan Coben or Samuel R. Delany?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 4.563040024716152e-09
# pred:  Who founded the largest brewery in Maryland?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 2.202381494555949e-09
# pred:  The Structure of Liberty is a book by Randy Barnett which offers a liberal conception of justice which emphasizes freedom, individual liberty, and voluntary association as a core principle, and is a collection of political philosophies and movements that uphold liberty as a core principle, and is a collection of what?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 0.004817931435131867
# pred:  In what state is the Baltimore County where the Lutherville Historic District is located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 3.0706628282890904e-09
# pred:  Carolus Nolet is the chairman of a company based in what Netherlands town?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 0.5296074932979102
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball who is currently coached by Brandon Schneider?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 3.735229177830252e-09
# pred:  Joseph Reiser was a general manager of which luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.722589422866631e-05
# pred:  Which province in Sicily is the birthplace of the preeminent mathematician and engineer Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.14576846148886236
# pred:  Deanna Oliver is the producer of "My Favorite Martian" and also worked with Sherri Stoner on what fantasy comedy loosely based on the Harvey Comics cartoon character Casper the Friendly Ghost created by Seymour Reit and Joe Oriolo?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.11639966908780695
# pred:  Are Werther and Odyssey from the same country?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 4.8157131074181714e-05
# pred:  Gregor Fisher had a role in which 2003 Christmas-themed romantic comedy?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.758250573156499e-05
# pred:  Dexter Jackson played college football at a university located in what Florida beach?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.28917849327562545
# pred:  Where is the headquarters of the regional airline subsidiary of Republic Airways Holdings that operates service as American Eagle, Delta Connection, and United Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.7972388123141377e-05
# pred:  In what part of southern England can the SETsquared Partnership be found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.327524290077678e-13
# pred:  The Cosmic catastrophe is a thought experiment in which Isaac Newton's classical theory of gravity was a deficiency in Newton's theory. In what year did Albert Einstein win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.14235660819617285
# Scores: {'TotalScore': 30.41570248843125, 'BERTScore': 0.4693670513277704, 'Bleu1': 0.38570507467683895, 'Bleu2': 0.27256888063670615, 'Bleu3': 0.19571253504696914, 'Bleu4': 0.1389469984408546}
# Epoch 2/20: 100%|██████████| 64/64 [11:59<00:00, 11.24s/batch, loss=1.0497]
# Average Loss: 1.0414
# Validation Epoch 1: 11batch [01:50, 10.03s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.51 seconds, 85.87 sentences/sec
# {'testlen': 635, 'reflen': 749, 'guess': [635, 591, 547, 503], 'correct': [286, 130, 66, 31]}
# ratio: 0.8477970627492019
# pred:  Are Plantago and Trichosanthes both types of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 1.1868405217902023e-12
# pred:  Lopamudra Raut was a contestant of what season of Indian reality TV series "Bigg Boss"?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.3693055762206496e-05
# pred:  Which Republican U.S. Senator was elected to the open U.S. Senate seat in 2012 and was narrowly elected to his first full term?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 3.6592701640592855e-13
# pred:  Moe Szyslak first appeared in an episode that originally aired on the Fox network in the United States on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 3.7551521143520844e-13
# pred:  Are the bands The Shipping News and Gene from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 0.22172045041645957
# pred:  Which American author is also a science fiction author, Harlan Coben or Samuel R. Delany?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 4.563040024716152e-09
# pred:  Who founded the largest brewery in Maryland?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 2.202381494555949e-09
# pred:  The Structure of Liberty is a book by Randy Barnett which offers a liberal conception of justice which emphasizes freedom, individual liberty, and voluntary association as a core principle, and is a collection of political philosophies and movements that uphold liberty as a core principle, and is a collection of what?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 0.004817931435131867
# pred:  In what state is the Baltimore County where the Lutherville Historic District is located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 3.0706628282890904e-09
# pred:  Carolus Nolet is the chairman of a company based in what Netherlands town?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 0.5296074932979102
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game for the team coached by Brandon Schneider?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 3.6467882407545897e-09
# pred:  Joseph Reiser was a general manager of which luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.722589422866631e-05
# pred:  What province in Sicily is the birthplace of the preeminent mathematician and engineer Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.15071676256676306
# pred:  Deanna Oliver is the producer of "My Favorite Martian" and also worked with Sherri Stoner on what fantasy comedy loosely based on the character Casper the Friendly Ghost created by Seymour Reit and Joe Oriolo?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.12748223149554716
# pred:  Are Werther and Odyssey both written by the same person?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 4.234740345501969e-05
# pred:  Gregor Fisher had a role in which 2003 Christmas-themed romantic comedy?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.758250573156499e-05
# pred:  Dexter Jackson played college football at a university located in what Florida beach?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.28917849327562545
# pred:  Where is the headquarters of the regional airline subsidiary of Republic Airways Holdings that operates service as American Eagle, Delta Connection, and United Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.7972388123141377e-05
# pred:  In what part of southern England can the SETsquared Partnership be found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.327524290077678e-13
# pred:  The Cosmic catastrophe is a thought experiment in which Isaac Newton's classical theory of gravity would be to instantaneously disappear. In what year did Albert Einstein win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.14151680409546447
# Scores: {'TotalScore': 30.356193782074918, 'BERTScore': 0.46944833326746116, 'Bleu1': 0.37637821615660827, 'Bleu2': 0.2630305913706492, 'Bleu3': 0.191073489301132, 'Bleu4': 0.1376755423740372}
# Epoch 3/20: 100%|██████████| 64/64 [11:57<00:00, 11.21s/batch, loss=1.0393]
# Average Loss: 1.0248
# Validation Epoch 2: 11batch [01:55, 10.51s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.52 seconds, 84.83 sentences/sec
# {'testlen': 635, 'reflen': 793, 'guess': [635, 591, 547, 503], 'correct': [301, 145, 81, 44]}
# ratio: 0.8007566204277418
# pred:  Are Plantago and Trichosanthes both types of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 1.1868405217902023e-12
# pred:  Lopamudra Raut was a contestant of what season of Indian reality TV series "Bigg Boss"?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.3693055762206496e-05
# pred:  Which Republican U.S. Senator from Nevada was elected to the open U.S. Senate seat in 2012 and was narrowly elected to his first full term over Shelley Berkley?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.9307894654014826e-13
# pred:  Moe Szyslak first appeared in an episode that originally aired on the Fox network in the United States on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 3.7551521143520844e-13
# pred:  Are The Shipping News and Gene both rock bands?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 0.767279645743035
# pred:  Which American author is also a science fiction author, Harlan Coben or Samuel R. Delany?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 4.563040024716152e-09
# pred:  Who founded the largest brewery in Maryland?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 2.202381494555949e-09
# pred:  The Structure of Liberty is a book by Randy Barnett which offers a liberal conception of justice which emphasizes freedom, individual liberty, and voluntary association as a core principle, and is a collection of political philosophies and movements that uphold liberty as a core principle, and is a collection of what?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 0.004817931435131867
# pred:  In what state is the Baltimore County where the Lutherville Historic District is located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 3.0706628282890904e-09
# pred:  Carolus Nolet is the chairman of a company based in what Netherlands town?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 0.5296074932979102
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game for the team coached by Brandon Schneider?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 3.6467882407545897e-09
# pred:  Joseph Reiser was a general manager of which luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.722589422866631e-05
# pred:  What province in Sicily is named after the birthplace of the preeminent mathematician and engineer Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.15071676256676306
# pred:  Deanna Oliver is the producer of "My Favorite Martian" and also worked with Sherri Stoner on what movie loosely based on the character Casper the Friendly Ghost created by Seymour Reit and Joe Oriolo?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.13369967344868058
# pred:  Are Werther and Odyssey both based on Johann Wolfgang von Goethe's novel "The Sorrows of Young Werther"?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 1.5578739118094252e-05
# pred:  Gregor Fisher had a role in which 2003 Christmas-themed romantic comedy?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.758250573156499e-05
# pred:  Dexter Jackson played college football at a university located in what Florida beach?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.28917849327562545
# pred:  Where is the headquarters of the regional airline subsidiary of Republic Airways Holdings that operates service as American Eagle, Delta Connection, and United Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.7972388123141377e-05
# pred:  In what part of southern England can the Epipactis leptochila be found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.327524290077678e-13
# pred:  The Cosmic catastrophe is a thought experiment in which Isaac Newton's classical theory of gravity is a deficiency in Newton's theory. In what year did Albert Einstein win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.14235660819617285
# Total score: 30.493778307887133 -> 31.32173323498743
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 31.32173323498743, 'BERTScore': 0.4728215678425675, 'Bleu1': 0.3696001136260889, 'Bleu2': 0.26590467417154184, 'Bleu3': 0.2013552637102933, 'Bleu4': 0.15361309685718108}
# Epoch 4/20: 100%|██████████| 64/64 [11:56<00:00, 11.20s/batch, loss=1.0217]
# Average Loss: 1.0169
# Validation Epoch 3: 11batch [01:44,  9.46s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.47 seconds, 94.04 sentences/sec
# {'testlen': 635, 'reflen': 731, 'guess': [635, 591, 547, 503], 'correct': [291, 142, 80, 44]}
# ratio: 0.8686730506144068
# pred:  Are Plantago and Trichosanthes both types of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 1.1868405217902023e-12
# pred:  Lopamudra Raut was a contestant of what season of Indian reality TV series "Bigg Boss"?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.3693055762206496e-05
# pred:  Which Republican U.S. Senator was elected to the seat that was held on November 6, 2012?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 3.4159919055542935e-13
# pred:  Moe Szyslak first appeared in an episode that originally aired on the Fox network in the United States on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 3.7551521143520844e-13
# pred:  Are The Shipping News and Gene both rock bands?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 0.767279645743035
# pred:  Which American author is also a science fiction author, Harlan Coben or Samuel R. Delany?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 4.563040024716152e-09
# pred:  Who founded the largest brewery in Maryland?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 2.202381494555949e-09
# pred:  The Structure of Liberty is a book by Randy Barnett which offers a theory of law and what?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 0.13062683534521727
# pred:  What state is the Lutherville Historic District located in and the third-most populous county in the United States?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 3.311958534021689e-13
# pred:  Carolus Nolet is the chairman of a company based in what Netherlands town?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 0.5296074932979102
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game of the week on Fox Sports 1 and the Jayhawks women's basketball team currently coached by Brandon Schneider?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 1.1080714713239792e-05
# pred:  Joseph Reiser was a general manager of which luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.722589422866631e-05
# pred:  What province in Sicily is named after the birthplace of the preeminent mathematician and engineer Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.15071676256676306
# pred:  Deanna Oliver is the producer of "My Favorite Martian" and also worked with Sherri Stoner on what movie loosely based on the character Casper the Friendly Ghost created by Seymour Reit and Joe Oriolo?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.13369967344868058
# pred:  Are Werther and Odyssey both written by the same person?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 4.234740345501969e-05
# pred:  Gregor Fisher had a role in which 2003 Christmas-themed romantic comedy film?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 0.2557665696563079
# pred:  Dexter Jackson played college football at a university located in what Florida beach?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.28917849327562545
# pred:  Where is the headquarters of the American airline holding corporation that owns the regional airline subsidiary of Republic Airways Holdings that operates service as American Eagle, Delta Connection, and United Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.266492785417979e-05
# pred:  In what part of southern England can the Epipactis leptochila be found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.327524290077678e-13
# pred:  The Cosmic catastrophe is a thought experiment in which Isaac Newton's classical theory of gravity would be to instantaneously disappear. In what year did this German-born theoretical physicist receive the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.12995210843334826
# Total score: 31.32173323498743 -> 31.645146140327746
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 31.645146140327746, 'BERTScore': 0.4663528789850799, 'Bleu1': 0.3939690862383048, 'Bleu2': 0.2852679262755679, 'Bleu3': 0.21709532805270562, 'Bleu4': 0.16655004382147504}
# Epoch 5/20: 100%|██████████| 64/64 [11:55<00:00, 11.19s/batch, loss=1.0550]
# Average Loss: 1.0180
# Validation Epoch 4: 11batch [01:46,  9.73s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.44 seconds, 101.09 sentences/sec
# {'testlen': 635, 'reflen': 765, 'guess': [635, 591, 547, 503], 'correct': [300, 149, 86, 48]}
# ratio: 0.8300653594760391
# pred:  Are Plantago and Trichosanthes both types of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 1.1868405217902023e-12
# pred:  Lopamudra Raut was a contestant of what season of Indian reality TV series "Bigg Boss"?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.3693055762206496e-05
# pred:  Which Republican U.S. Senator from Nevada was elected to the Senate seat in 2012 and was narrowly elected to his first full term over Shelley Berkley?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 3.275213114053928e-13
# pred:  Moe Szyslak first appeared in an episode that originally aired in the United States on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 4.753592194894166e-13
# pred:  Are the bands The Shipping News and Gene both from the same country?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 0.2896204681979632
# pred:  Which American author has been a guest of honor at Readercon, Samuel R. Delany or Harlan Coben?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 0.2750524266249475
# pred:  Who founded the largest brewery in Maryland?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 2.202381494555949e-09
# pred:  The Structure of Liberty is a book by Randy Barnett which offers a collection of political philosophies and movements that uphold liberty as a core principle, and is a collection of what?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 0.03221218100543073
# pred:  In what state is the Baltimore County where the Lutherville Historic District is located?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 3.0706628282890904e-09
# pred:  Carolus Nolet is the chairman of a company based in what Netherlands town?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 0.5296074932979102
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game for a team currently coached by Brandon Schneider?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 3.80627192398075e-09
# pred:  Joseph Reiser was a general manager of which luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.722589422866631e-05
# pred:  What province in Sicily is the birthplace of the preeminent mathematician and engineer Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.15071676256676306
# pred:  Deanna Oliver is the producer of "My Favorite Martian" and also worked with Sherri Stoner on what movie based on a character created by Seymour Reit and Joe Oriolo?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.19200504334206994
# pred:  Do Werther and Odyssey have the same number of acts?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 5.035983349060022e-09
# pred:  Gregor Fisher had a role in which 2003 Christmas-themed romantic comedy?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.758250573156499e-05
# pred:  Dexter Jackson played college football at a university located in what Florida beach?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.28917849327562545
# pred:  Where is the headquarters of the American regional airline subsidiary of Republic Airways Holdings that operates service as American Eagle, Delta Connection, and United Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.709586441127924e-05
# pred:  In what part of southern England can the SETsquared Partnership be found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.327524290077678e-13
# pred:  The Cosmic catastrophe is a thought experiment in which Isaac Newton's classical theory of gravity would be to instantaneously disappear. In what year did this German-born theoretical physicist receive the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.12995210843334826
# Total score: 31.645146140327746 -> 32.406677130742175
# checkpoint_best.pkl已存储至/kaggle/working/
# Scores: {'TotalScore': 32.406677130742175, 'BERTScore': 0.48059219968589867, 'Bleu1': 0.38497882981933795, 'Bleu2': 0.2812305376567426, 'Bleu3': 0.2163922981586453, 'Bleu4': 0.16754134292894476}
# Epoch 6/20: 100%|██████████| 64/64 [11:56<00:00, 11.20s/batch, loss=0.9460]
# Average Loss: 1.0004
# Validation Epoch 5: 11batch [02:01, 11.01s/batch]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.49 seconds, 89.06 sentences/sec
# {'testlen': 635, 'reflen': 790, 'guess': [635, 591, 547, 503], 'correct': [291, 143, 82, 46]}
# ratio: 0.8037974683534129
# pred:  Are Plantago and Trichosanthes both types of plants?
# true:  Are Trichosanthes and Plantago both forms of plant life?
# bleu4: 1.1868405217902023e-12
# pred:  Lopamudra Raut was a contestant of what season of Indian reality TV series "Bigg Boss"?
# true:  In which season of the Indian reality TV show "Big Boss" did the model Lopamundra Raut participate?
# bleu4: 2.3693055762206496e-05
# pred:  Which Republican U.S. Senator was elected to the seat that was held on November 6, 2012 and was narrowly elected to his first full term over Shelley Berkley?
# true:  The 2012 United States Senate election in Nevada concluded with a close victory for which current Republican incumbent?
# bleu4: 2.3307710740126315e-13
# pred:  Moe Szyslak first appeared in an episode that originally aired in the United States on what date?
# true:  When was the Simpson's episode broadcasted that introduced the character Morris "Moe" Szyslak?
# bleu4: 4.753592194894166e-13
# pred:  Are The Shipping News and Gene both rock bands?
# true:  Are Shipping News and Gene both rock bands?
# bleu4: 0.767279645743035
# pred:  Which author is also a science fiction author, Harlan Coben or Samuel R. Delany?
# true:  Who is the science fiction writer, Samuel R. Delany or Harlan Coben?
# bleu4: 4.959586680991433e-09
# pred:  Who founded the largest brewery in Maryland?
# true:  Who was the initial female founder of the brewery that was acquired in 2006 by the biggest brewery in the state of Maryland?
# bleu4: 2.202381494555949e-09
# pred:  The Structure of Liberty is a book by Randy Barnett which offers a collection of political philosophies and movements that uphold liberty as a core principle, and is a collection of what?
# true:  What type of ideologies is The Structure of Liberty about?
# bleu4: 0.03221218100543073
# pred:  What state is the Lutherville Historic District located in?
# true:  What characteristics do Lutherville and Baltimore County share?
# bleu4: 9.218141453123176e-13
# pred:  Carolus Nolet is the chairman of a company based in what Netherlands town?
# true:  Carolus Nolet is the chairman of a company from which city in the Netherlands?
# bleu4: 0.5296074932979102
# pred:  Who is the primary analyst for the Big 12 Conference women's basketball game of the week for the women's basketball team currently coached by Brandon Schneider?
# true:  Who serves as an analyst for a TV network for the Kansas Jayhawks women's basketball team?
# bleu4: 2.5063984598916204e-09
# pred:  Joseph Reiser was a general manager of which luxury watchmaker based in Biel/Bienne, Switzerland?
# true:  What is the name of the company operated by Joseph Reiser located in Biel/Bienne, Switzerland?
# bleu4: 2.722589422866631e-05
# pred:  What province in Sicily is the birthplace of the preeminent mathematician and engineer Archimedes?
# true:  What Province in Sicily, established in the eighth century B.C., was the birthplace of the renowned historical mathematician Archimedes?
# bleu4: 0.15071676256676306
# pred:  Deanna Oliver is the producer of "My Favorite Martian" and also worked with Sherri Stoner on what movie based on a character created by Seymour Reit and Joe Oriolo?
# true:  Which movie, based on a cartoon character by Seymour Reit and Joe Oriolo, did Deanna Oliver and Sherri Stoner work on?
# bleu4: 0.19200504334206994
# pred:  Are Werther and Sorrows of Werther from the same country?
# true:  Are Werther and The Odyssey both musicals?
# bleu4: 3.3677650407065834e-05
# pred:  Gregor Fisher had a role in which 2003 Christmas-themed romantic comedy?
# true:  What 2003 Christmas-themed romantic comedy did Gregor Fisher participate in?
# bleu4: 3.758250573156499e-05
# pred:  Dexter Jackson played college football at a university located in what beach?
# true:  Where is the historically black college where Dexter Jackson played college football located?
# bleu4: 0.2891784932978699
# pred:  Where is the headquarters of the American airline holding company that owns the regional airline subsidiary of Republic Airways Holdings that operates service as American Eagle, Delta Connection, and United Express?
# true:  The Republic Airways Holdings company is located in the same place as which of its regional airline subsidiary's main offices?
# bleu4: 1.3002955995458437e-05
# pred:  In what part of southern England can the Epipactis leptochila be found?
# true:  Is Liverpool located in northern or southern England?
# bleu4: 5.327524290077678e-13
# pred:  The Cosmic catastrophe is a thought experiment in which Isaac Newton's classical theory of gravity is a deficiency in Newton's theory. In what year did this German-born theoretical physicist, who saw a deficiency in Newton's theory, win the Nobel Prize in Physics?
# true:  The physicist that noticed a flaw in Newton's classical theory of gravity received a Nobel Prize in what year?
# bleu4: 0.08864601011037372
# Scores: {'TotalScore': 31.503938833254708, 'BERTScore': 0.47538880533962086, 'Bleu1': 0.35901316497979363, 'Bleu2': 0.26087053019531914, 'Bleu3': 0.19993518375183045, 'Bleu4': 0.1546899713254733}
# Epoch 7/20:   0%|          | 0/64 [00:04<?, ?batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 10
#       2 config2={
#       3     'pg_num':7,
#       4     'max_source_length':1024,
#    (...)
#       7     'epochs':20,
#       8 }
#       9 trainer_config=get_trainer_config(**config2)
# ---> 10 train(model,trainer_config,True)
#
# Cell In[14], line 41, in train(model, config, show)
#      38 loss = outputs.loss
#      39 loss.backward()
# ---> 41 loss_t = loss.detach().cpu()
#      42 epoch_loss += loss_t[0] if len(loss_t.shape) > 0 else loss_t.numpy()
#      43 batch_loss +=loss_t[0] if len(loss_t.shape) > 0 else loss_t.numpy()
#
# KeyboardInterrupt:

# %% [markdown]
# ## 在测试集上测试

# %%
with open(args.test_data_path, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)
test_id_list = [item['_id'] for item in data]

train_data_loader,dev_data_loader,test_data_loader=prepare_data(tokenizer,config=get_eval_config())
test_generator=get_infinite_data(test_data_loader)
def get_test_batch():
    return test_generator.__next__()

# 测试
generated_questions = []
generated_questions_dict = []
model.eval()
with tqdm(total=len(test_data_loader), desc=f'Test epoch {1}/{1}', unit='batch') as pbar:
    for i in range(len(test_data_loader)):
        batch=get_test_batch()
        with torch.no_grad():
            input_ids = batch['input_ids'].to(device)
            attention_mask=batch['attention_mask'].to(device)
            generated_ids = model.generate(input_ids=input_ids, 
                                           max_new_tokens=128,
                                           do_sample=False)
            #preds_list.extend(tokenizer.batch_decode(generated_ids, skip_special_tokens=True))
        #generated_ids = generate_question(batch)
        qs = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        generated_questions.extend(qs)
        pbar.update(1)

for _,item in enumerate(generated_questions):
    generated_questions_dict.append({'_id':test_id_list[_],'question':item})

with open('output.json', 'w', encoding='utf-8') as json_file:
        json.dump(generated_questions_dict, json_file, ensure_ascii=False, indent=4)
